# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

# Import our input dataset
charity_df = pd.read_csv('charity_data.csv')
charity_df.head()
# Out:
# C:\Users\Helen\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Helen\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Helen\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# Features: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, INCOME_AMT, ASK_AMT
#
# Target: IS_SUCCESSFUL
#
# Remove: EIN, NAME, CLASSIFICATION, STATUS, SPECIAL_CONSIDERATIONS

# %%
charity_df.columns
# Out:
# Index(['EIN', 'NAME', 'APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION',
#        'USE_CASE', 'ORGANIZATION', 'STATUS', 'INCOME_AMT',
#        'SPECIAL_CONSIDERATIONS', 'ASK_AMT', 'IS_SUCCESSFUL'],
#       dtype='object')

# %%
# Drop columns
charity_copy = charity_df.drop(columns=['NAME', 'CLASSIFICATION', 'STATUS', 'SPECIAL_CONSIDERATIONS'], axis = 1)
charity_copy.head()
# Out:
#         EIN APPLICATION_TYPE       AFFILIATION      USE_CASE  ORGANIZATION  \
# 0  10520599              T10       Independent    ProductDev   Association
# 1  10531628               T3       Independent  Preservation  Co-operative
# 2  10547893               T5  CompanySponsored    ProductDev   Association
# 3  10553066               T3  CompanySponsored  Preservation         Trust
# 4  10556103               T3       Independent     Heathcare         Trust
#
#       INCOME_AMT  ASK_AMT  IS_SUCCESSFUL
# 0              0     5000              1
# 1         1-9999   108590              1
# 2              0     5000              0
# 3    10000-24999     6692              1
# 4  100000-499999   142590              1

# %%
# Check for null values
charity_copy.isnull().sum()
# Out:
# EIN                 0
# APPLICATION_TYPE    0
# AFFILIATION         0
# USE_CASE            0
# ORGANIZATION        0
# INCOME_AMT          0
# ASK_AMT             0
# IS_SUCCESSFUL       0
# dtype: int64

# %%
# Print out the Country value counts
ask_amt_counts = charity_copy.ASK_AMT.value_counts()
ask_amt_counts
# Out:
# 5000       25398
# 10478          3
# 15583          3
# 6725           3
# 63981          3
#            ...
# 772556         1
# 70103          1
# 27096          1
# 25049          1
# 1138700        1
# Name: ASK_AMT, Length: 8747, dtype: int64

# %%
# Visualize the value counts
ask_amt_counts.plot.density()

# %%
# Check Max ask_amt
charity_copy.describe()
# Out:
#                 EIN       ASK_AMT  IS_SUCCESSFUL
# count  3.429900e+04  3.429900e+04   34299.000000
# mean   5.191852e+08  2.769199e+06       0.532406
# std    2.451472e+08  8.713045e+07       0.498956
# min    1.052060e+07  5.000000e+03       0.000000
# 25%    2.748482e+08  5.000000e+03       0.000000
# 50%    4.656317e+08  5.000000e+03       1.000000
# 75%    7.526117e+08  7.742000e+03       1.000000
# max    9.960869e+08  8.597806e+09       1.000000

# %%
# Determine which values to replace
replace_ask_amt = list(ask_amt_counts[ask_amt_counts < 5].index)

# Replace in DataFrame
for amount in replace_ask_amt:
    charity_copy.ASK_AMT = charity_copy.ASK_AMT.replace(amount,"Other")


# Check to make sure binning was successful
charity_copy.ASK_AMT.value_counts()
# Out:
# 5000     25398
# Other     8901
# Name: ASK_AMT, dtype: int64

# %%
# Check dtypes
charity_copy.dtypes
# Out:
# EIN                  int64
# APPLICATION_TYPE    object
# AFFILIATION         object
# USE_CASE            object
# ORGANIZATION        object
# INCOME_AMT          object
# ASK_AMT             object
# IS_SUCCESSFUL        int64
# dtype: object

# %%
# Encode ASK_AMT
charity_copy = pd.get_dummies(charity_copy, columns=['ASK_AMT'])
charity_copy.head()
# Out:
#         EIN APPLICATION_TYPE       AFFILIATION      USE_CASE  ORGANIZATION  \
# 0  10520599              T10       Independent    ProductDev   Association
# 1  10531628               T3       Independent  Preservation  Co-operative
# 2  10547893               T5  CompanySponsored    ProductDev   Association
# 3  10553066               T3  CompanySponsored  Preservation         Trust
# 4  10556103               T3       Independent     Heathcare         Trust
#
#       INCOME_AMT  IS_SUCCESSFUL  ASK_AMT_5000  ASK_AMT_Other
# 0              0              1             1              0
# 1         1-9999              1             0              1
# 2              0              0             1              0
# 3    10000-24999              1             0              1
# 4  100000-499999              1             0              1

# %%
# Generate our categorical variable list

charity_cat = ['APPLICATION_TYPE', 'AFFILIATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT']

# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)
charity_df_copy = pd.DataFrame(charity_copy)
# do one-hotencoding for each column (independent variables)

for cat in charity_cat:
    
    # Fit and transform the OneHotEncoder using the categorical variable list
    encode_df = pd.DataFrame(enc.fit_transform(charity_copy[[cat]]))

    # Add the encoded variable names to the DataFrame
    encode_df.columns = enc.get_feature_names([cat])
    
    # merge all the encoded columns back one data frame
    charity_df_copy = pd.concat([charity_df_copy.reset_index(drop=True), encode_df.reset_index(drop=True)], axis=1)
    
# Drop original columns
charity_df_copy = charity_df_copy.drop(charity_cat, 1)

# Set EIN as index
charity_df_copy = charity_df_copy.set_index('EIN')

charity_df_copy.head()
# Out:
#           IS_SUCCESSFUL  ASK_AMT_5000  ASK_AMT_Other  APPLICATION_TYPE_T10  \
# EIN
# 10520599              1             1              0                   1.0
# 10531628              1             0              1                   0.0
# 10547893              0             1              0                   0.0
# 10553066              1             0              1                   0.0
# 10556103              1             0              1                   0.0
#
#           APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  \
# EIN
# 10520599                   0.0                   0.0                   0.0
# 10531628                   0.0                   0.0                   0.0
# 10547893                   0.0                   0.0                   0.0
# 10553066                   0.0                   0.0                   0.0
# 10556103                   0.0                   0.0                   0.0
#
# ...

# %%
# Check the number of unique values in each column
charity_df_copy.nunique()
# Out:
# IS_SUCCESSFUL                   2
# ASK_AMT_5000                    2
# ASK_AMT_Other                   2
# APPLICATION_TYPE_T10            2
# APPLICATION_TYPE_T12            2
# APPLICATION_TYPE_T13            2
# APPLICATION_TYPE_T14            2
# APPLICATION_TYPE_T15            2
# APPLICATION_TYPE_T17            2
# APPLICATION_TYPE_T19            2
# APPLICATION_TYPE_T2             2
# APPLICATION_TYPE_T25            2
# APPLICATION_TYPE_T29            2
# APPLICATION_TYPE_T3             2
# APPLICATION_TYPE_T4             2
# APPLICATION_TYPE_T5             2
# APPLICATION_TYPE_T6             2
# APPLICATION_TYPE_T7             2
# APPLICATION_TYPE_T8             2
# APPLICATION_TYPE_T9             2
# AFFILIATION_CompanySponsored    2
# AFFILIATION_Family/Parent       2
# AFFILIATION_Independent         2
# AFFILIATION_National            2
# AFFILIATION_Other               2
# AFFILIATION_Regional            2
# USE_CASE_CommunityServ          2
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = charity_df_copy["IS_SUCCESSFUL"].values
X = charity_df_copy.drop(["IS_SUCCESSFUL"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78, stratify=y)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Check number of input features
len(X_train_scaled[0])
# Out:
# 43

# %%
# Define the model - deep neural net
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  30
hidden_nodes_layer2 = 13

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Helen\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 30)                1320
# _________________________________________________________________
# dense_1 (Dense)              (None, 13)                403
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 14
# ...
# Total params: 1,737
# Trainable params: 1,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From C:\Users\Helen\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 25724/25724 [==============================] - 1s 45us/sample - loss: 0.5871 - acc: 0.7154
# Epoch 2/100
# 25724/25724 [==============================] - 1s 41us/sample - loss: 0.5709 - acc: 0.7252
# Epoch 3/100
# 25724/25724 [==============================] - 1s 42us/sample - loss: 0.5686 - acc: 0.7251
# Epoch 4/100
# 25724/25724 [==============================] - 1s 45us/sample - loss: 0.5681 - acc: 0.7247
# Epoch 5/100
# 25724/25724 [==============================] - 1s 42us/sample - loss: 0.5677 - acc: 0.7254
# Epoch 6/100
# 25724/25724 [==============================] - 1s 42us/sample - loss: 0.5668 - acc: 0.72631s - loss: 0
# Epoch 7/100
# 25724/25724 [==============================] - 1s 40us/sample - loss: 0.5666 - acc: 0.7264
# Epoch 8/100
# 25724/25724 [==============================] - 1s 40us/sample - loss: 0.5662 - acc: 0.7264
# Epoch 9/100
# 25724/25724 [==============================] - 1s 40us/sample - loss: 0.5661 - acc: 0.7267
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8575/8575 - 0s - loss: 0.5690 - acc: 0.7255
# Loss: 0.569048054294753, Accuracy: 0.7254810333251953

# %% [markdown]
# ## Other Models

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Create a random forest classifier.
rf_model = RandomForestClassifier(n_estimators=128, random_state=78)

# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# Evaluate the model
y_pred = rf_model.predict(X_test_scaled)
print(f" Random forest predictive accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Random forest predictive accuracy: 0.726

# %%
from sklearn.linear_model import LogisticRegression

# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy (lbfgs): {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy (lbfgs): 0.722
# C:\Users\Helen\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="newton-cg",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy (newton-cg): {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy (newton-cg): 0.722

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="saga",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy (saga): {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy (saga): 0.722

# %% [markdown]
# ## Attempt #1 (2 Output layers)

# %%
# Generate our categorical variable list

charity_cat = ['APPLICATION_TYPE', 'AFFILIATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'IS_SUCCESSFUL']

# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)
charity_copy_new = pd.DataFrame(charity_copy)
# do one-hotencoding for each column (independent variables)

for cat in charity_cat:
    
    # Fit and transform the OneHotEncoder using the categorical variable list
    encode_df = pd.DataFrame(enc.fit_transform(charity_copy[[cat]]))

    # Add the encoded variable names to the DataFrame
    encode_df.columns = enc.get_feature_names([cat])
    
    # merge all the encoded columns back one data frame
    charity_copy_new = pd.concat([charity_copy_new.reset_index(drop=True), encode_df.reset_index(drop=True)], axis=1)
    
# Drop original columns
charity_copy_new = charity_copy_new.drop(charity_cat, 1)

# Set EIN as index
charity_copy_new = charity_copy_new.set_index('EIN')

charity_copy_new.head()
# Out:
#           ASK_AMT_5000  ASK_AMT_Other  APPLICATION_TYPE_T10  \
# EIN
# 10520599             1              0                   1.0
# 10531628             0              1                   0.0
# 10547893             1              0                   0.0
# 10553066             0              1                   0.0
# 10556103             0              1                   0.0
#
#           APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  \
# EIN
# 10520599                   0.0                   0.0                   0.0
# 10531628                   0.0                   0.0                   0.0
# 10547893                   0.0                   0.0                   0.0
# 10553066                   0.0                   0.0                   0.0
# 10556103                   0.0                   0.0                   0.0
#
#           APPLICATION_TYPE_T15  APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  \
# EIN
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = charity_copy_new[["IS_SUCCESSFUL_0", "IS_SUCCESSFUL_1"]].values
X = charity_copy_new.drop(["IS_SUCCESSFUL_0", "IS_SUCCESSFUL_1"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78, stratify=y)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Check number of input features
len(X_train_scaled[0])
# Out:
# 43

# %%
# Define the model - deep neural net
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  30
hidden_nodes_layer2 = 13

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=2, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_6 (Dense)              (None, 30)                1320
# _________________________________________________________________
# dense_7 (Dense)              (None, 13)                403
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 28
# ...
# Total params: 1,751
# Trainable params: 1,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 25724/25724 [==============================] - 1s 44us/sample - loss: 0.5956 - acc: 0.7130
# Epoch 2/100
# 25724/25724 [==============================] - 1s 41us/sample - loss: 0.5695 - acc: 0.7271
# Epoch 3/100
# 25724/25724 [==============================] - 1s 40us/sample - loss: 0.5665 - acc: 0.7281
# Epoch 4/100
# 25724/25724 [==============================] - 1s 40us/sample - loss: 0.5654 - acc: 0.7275
# Epoch 5/100
# 25724/25724 [==============================] - 1s 41us/sample - loss: 0.5648 - acc: 0.7272
# Epoch 6/100
# 25724/25724 [==============================] - 1s 41us/sample - loss: 0.5641 - acc: 0.7292
# Epoch 7/100
# 25724/25724 [==============================] - 1s 40us/sample - loss: 0.5633 - acc: 0.7279
# Epoch 8/100
# 25724/25724 [==============================] - 1s 40us/sample - loss: 0.5633 - acc: 0.7287
# Epoch 9/100
# 25724/25724 [==============================] - 1s 40us/sample - loss: 0.5625 - acc: 0.7287
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8575/8575 - 0s - loss: 0.5754 - acc: 0.7200
# Loss: 0.5754284404179097, Accuracy: 0.7200000286102295

# %% [markdown]
# ## Attempt #2 (Additional Neurons)

# %% [markdown]
# We are going to use stay consistent with two output layers for Attempt #2.

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Check the number of input features
len(X_train_scaled[0])
# Out:
# 43

# %%
# Define the model - deep neural net (doule the amount of input features)
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  43
hidden_nodes_layer2 = 43


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=2, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_9 (Dense)              (None, 43)                1892
# _________________________________________________________________
# dense_10 (Dense)             (None, 43)                1892
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 88
# ...
# Total params: 3,872
# Trainable params: 3,872
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 25724/25724 [==============================] - 1s 46us/sample - loss: 0.5854 - acc: 0.7179
# Epoch 2/100
# 25724/25724 [==============================] - 1s 42us/sample - loss: 0.5682 - acc: 0.7265
# Epoch 3/100
# 25724/25724 [==============================] - 1s 42us/sample - loss: 0.5660 - acc: 0.7264
# Epoch 4/100
# 25724/25724 [==============================] - 1s 42us/sample - loss: 0.5651 - acc: 0.7280
# Epoch 5/100
# 25724/25724 [==============================] - 1s 42us/sample - loss: 0.5644 - acc: 0.7286
# Epoch 6/100
# 25724/25724 [==============================] - 1s 42us/sample - loss: 0.5641 - acc: 0.7276
# Epoch 7/100
# 25724/25724 [==============================] - 1s 45us/sample - loss: 0.5635 - acc: 0.7302
# Epoch 8/100
# 25724/25724 [==============================] - 1s 44us/sample - loss: 0.5631 - acc: 0.7291
# Epoch 9/100
# 25724/25724 [==============================] - 1s 42us/sample - loss: 0.5629 - acc: 0.7284
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8575/8575 - 0s - loss: 0.5837 - acc: 0.7191
# Loss: 0.5836702176572283, Accuracy: 0.7190670371055603

# %% [markdown]
# ## Attempt #3 (Additional Hidden Layers)

# %% [markdown]
# We are going to use stay consistent with two output layers for Attempt #3.

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Check number of input features
len(X_train_scaled[0])
# Out:
# 43

# %% [markdown]
# Since the accuracy of the model reduced with additional neurons, we will go back to having the same number as our input features.

# %%
# Define the model - deep neural net
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  30
hidden_nodes_layer2 = 10
hidden_nodes_layer3 = 3

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=2, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_12 (Dense)             (None, 30)                1320
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                310
# _________________________________________________________________
# dense_14 (Dense)             (None, 3)                 33
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 8
# ...
# Total params: 1,671
# Trainable params: 1,671
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 25724/25724 [==============================] - 1s 44us/sample - loss: 0.6160 - acc: 0.7105
# Epoch 2/100
# 25724/25724 [==============================] - 1s 37us/sample - loss: 0.5843 - acc: 0.7262
# Epoch 3/100
# 25724/25724 [==============================] - 1s 37us/sample - loss: 0.5762 - acc: 0.7270
# Epoch 4/100
# 25724/25724 [==============================] - 1s 37us/sample - loss: 0.5729 - acc: 0.7272
# Epoch 5/100
# 25724/25724 [==============================] - 1s 38us/sample - loss: 0.5717 - acc: 0.7286
# Epoch 6/100
# 25724/25724 [==============================] - 1s 37us/sample - loss: 0.5709 - acc: 0.7282
# Epoch 7/100
# 25724/25724 [==============================] - 1s 39us/sample - loss: 0.5708 - acc: 0.7291
# Epoch 8/100
# 25724/25724 [==============================] - 1s 37us/sample - loss: 0.5705 - acc: 0.72880s - loss: 0.58
# Epoch 9/100
# 25724/25724 [==============================] - 1s 38us/sample - loss: 0.5699 - acc: 0.7282
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8575/8575 - 0s - loss: 0.5804 - acc: 0.7180
# Loss: 0.5803814468786945, Accuracy: 0.7180175185203552

# %% [markdown]
# ## Attempt #4 (Additional epochs)

# %% [markdown]
# Once again, we will add onto the other attempts to stay consistent.

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Check the number of input features
len(X_train_scaled[0])
# Out:
# 43

# %%
# Define the model - deep neural net
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  30
hidden_nodes_layer2 = 10
hidden_nodes_layer3 = 3

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=2, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_16 (Dense)             (None, 30)                1320
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                310
# _________________________________________________________________
# dense_18 (Dense)             (None, 3)                 33
# _________________________________________________________________
# dense_19 (Dense)             (None, 2)                 8
# ...
# Total params: 1,671
# Trainable params: 1,671
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model, but this time add additional epochs
fit_model = nn.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 25724/25724 [==============================] - 2s 65us/sample - loss: 0.6215 - acc: 0.7080
# Epoch 2/200
# 25724/25724 [==============================] - 1s 49us/sample - loss: 0.5862 - acc: 0.7249
# Epoch 3/200
# 25724/25724 [==============================] - 1s 47us/sample - loss: 0.5773 - acc: 0.7264
# Epoch 4/200
# 25724/25724 [==============================] - 1s 49us/sample - loss: 0.5741 - acc: 0.7270
# Epoch 5/200
# 25724/25724 [==============================] - 1s 46us/sample - loss: 0.5724 - acc: 0.7261
# Epoch 6/200
# 25724/25724 [==============================] - 1s 46us/sample - loss: 0.5702 - acc: 0.7273
# Epoch 7/200
# 25724/25724 [==============================] - 1s 47us/sample - loss: 0.5692 - acc: 0.7269
# Epoch 8/200
# 25724/25724 [==============================] - 1s 52us/sample - loss: 0.5687 - acc: 0.7278
# Epoch 9/200
# 25724/25724 [==============================] - 1s 46us/sample - loss: 0.5679 - acc: 0.7266
# Epoch 10/200
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8575/8575 - 0s - loss: 0.5779 - acc: 0.7205
# Loss: 0.5779025285515076, Accuracy: 0.7204664945602417
